# %%
import simpy as smp
from random import expovariate, random, randint, seed

# %%
CUSTOMER_DSTRB = [[0.5, 1], [0.3, 2], [0.1, 3], [0.1, 4]]
WAY_DSTRB = [[0.8, "hot"], [0.15, "cold"], [0.05, "drinks"]]
HOT_TIME  = [50, 120]
COLD_TIME = [30, 90]
HOT_WORKERS = 1
COLD_WORKERS = 1
CASHBOX_NUMBER = 2
MEAN_GAP = 30
CUSTOMER_NUMBER = 0
STUDETNTS = []
seed(42)
# seed_arrive = 11
# seed_groups = 17
# seed_way = 29
# seed_station_time = {"hot":31, "cold":43, "drinks":51}
# seed_cash_time    = {"hot":59, "cold":79, "drinks":91}

# %%
def print_time(s, sec):
    mins = str(int(sec // 60))
    secs = int(sec %  60)
    if secs // 10 == 0:
        secs = "0" + str(secs)
    else:
        secs = str(secs)
    print(s, mins + ":" + secs)

# %%
def discrete_rv(drv):
    if sum([val[0] for val in drv]) != 1:
        raise 1
    r = random()
    s = 0
    for pair in drv:
        if (r > s) and (r < (s + pair[0])):
            return pair[1]
        s += pair[0]

# %%
def gen_group(env, canteen):
    global CUSTOMER_NUMBER, STUDETNTS
    env.process(canteen.start())
    while True:
        yield env.timeout(expovariate(1 / MEAN_GAP))
        n = discrete_rv(CUSTOMER_DSTRB)
        for i in range(n):
            std = Student(env, canteen, CUSTOMER_NUMBER)
            STUDETNTS += [std]
            env.process(std.start())
            CUSTOMER_NUMBER += 1

# %%
class Student:
    def __init__(self, env, canteen, index):
        self.env = env
        self.canteen = canteen
        self.index = index
        self.service_time = 0
        self.cashbox_time = 0
        self.delays = {"hot":0, "cold":0, "cash":0}
        self.cash_wait = 0
        self.finished = 0
        
    def start(self):
        self.service_time = self.env.now
        self.way = discrete_rv(WAY_DSTRB)
        if self.way != "hot":
            print("LOLEL")
        print("Студент {0} направился к {1}".format(self.index, self.way))
        if self.way != "drinks":
            with self.canteen.stations[self.way][0].request() as req:
                self.canteen.stations[self.way][2] += 1
                wait = self.env.now
                yield req
                
                self.canteen.stations[self.way][2] -= 1
                self.delays[self.way] = self.env.now - wait
                print("Студент {0} начал обслуживание у {1}_station в {2}".format(self.index, self.way, self.env.now))
                
                yield self.env.process(self.canteen.stations[self.way][1](self))
                print("Студент {0} покинул {1}_station в {2}".format(self.index, self.way, self.env.now))
        
        print("Студент {0} начал обслуживание у drinks_station  в {1}".format(self.index, self.env.now))
        yield self.env.process(self.canteen.drinks_station(self))
        print("Студент {0} покинул drinks_station в {1}".format(self.index, self.env.now))
               
        cash_n, cashbox, q_len = min(self.canteen.cashboxes, key=lambda x: x[2])
        print([cbox[2] for cbox in self.canteen.cashboxes])
        print("Студент {0} прибыл к кассе #{1} в {2}".format(self.index, cash_n,  self.env.now))
        
        
        self.canteen.cashboxes[cash_n][2] += 1
        wait = self.env.now
        
        with cashbox.request() as cash_req:
            yield cash_req
            self.delays["cash"] = self.env.now - wait
            print("Студент {0} начал обслуживание у кассы #{1} в {2}".format(self.index, cash_n, self.env.now))
            
            yield self.env.process(self.canteen.cashbox(self))
            print("Студент {0} покинул кассу #{1} в {2}".format(self.index, cash_n, self.env.now))
            self.canteen.cashboxes[cash_n][2] -= 1
            
        self.finished = 1
        self.service_time = self.env.now - self.service_time
        print_time("Студент {0} обслуживался".format(self.index), self.service_time)

# %%
class Canteen:
    def __init__(self, env):
        self.env = env
        self.hot = smp.Resource(self.env, capacity=HOT_WORKERS)
        self.cold = smp.Resource(self.env, capacity=COLD_WORKERS)
        self.cashboxes = [[i, smp.Resource(self.env, capacity=1), 0] for i in range(CASHBOX_NUMBER)]
        self.stations = {"hot":[self.hot, self.hot_station, 0], "cold":[self.cold, self.cold_station, 0]}
    
    def hot_station(self, student):
        time = randint(HOT_TIME[0], HOT_TIME[1])
        student.cashbox_time += randint(20, 40)
        
        print("hot time:", time)
        yield student.env.timeout(time)
    
    def cold_station(self, student):
        time = randint(COLD_TIME[0], COLD_TIME[1])

        student.cashbox_time += randint(5, 15)
        
        print("{0} student's cold time:".format(student.index), time)
        yield student.env.timeout(time)
    
    def drinks_station(self, student):
        time = randint(5, 20)
        student.cashbox_time += randint(5, 10)
        
        print("drinks time:", time)
        yield student.env.timeout(time) 
    
    def cashbox(self, student):
        yield student.env.timeout(student.cashbox_time)
        
    def start(self):
        self.mean_hot_queue  = 0
        self.mean_cold_queue = 0
        self.mean_cash_queue = 0
        self.mean_all = 0
        
        self.max_hot_queue  = 0
        self.max_cold_queue = 0
        self.max_cash_queue = 0
        self.max_all = 0
        tick = 0
        while True:
            yield self.env.timeout(1)
            self.mean_hot_queue = self.mean_hot_queue * tick + self.stations["hot"][2]
            self.mean_cold_queue = self.mean_cold_queue * tick + self.stations["cold"][2]
            self.mean_cash_queue = self.mean_cash_queue * tick + sum([cash[2] for cash in self.cashboxes]) / CASHBOX_NUMBER
            all_students = self.stations["hot"][2] + self.stations["cold"][2] + sum([cash[2] for cash in self.cashboxes])
            self.mean_all = self.mean_all * tick + all_students
            tick += 1 
            
            self.mean_hot_queue /= tick
            self.mean_cold_queue /= tick
            self.mean_cash_queue /= tick
            self.mean_all /= tick
            
            if self.stations["hot"][2] > self.max_hot_queue:
                self.max_hot_queue = self.stations["hot"][2]
            if self.stations["cold"][2] > self.max_cold_queue:
                self.max_cold_queue = self.stations["cold"][2]
            if max([cash[2] for cash in self.cashboxes]) > self.max_cash_queue:
                self.max_cash_queue = max([cash[2] for cash in self.cashboxes])
            if all_students > self.max_all:
                self.max_all = all_students

# %%
env = smp.Environment()
cnt = Canteen(env)
env.process(gen_group(env, cnt))
env.run(until=90*60)
# Out:
# Студент 0 направился к hot
# Студент 0 начал обслуживание у hot_station в 30.601808618244032
# hot time: 63
# Студент 1 направился к hot
# Студент 2 направился к hot
# Студент 3 направился к hot
# Студент 0 покинул hot_station в 93.60180861824404
# Студент 0 начал обслуживание у drinks_station  в 93.60180861824404
# drinks time: 12
# Студент 1 начал обслуживание у hot_station в 93.60180861824404
# hot time: 85
# Студент 0 покинул drinks_station в 105.60180861824404
# [0, 0, 0]
# Студент 14 прибыл к кассе #0 в 389.68502114499535
# Студент 14 начал обслуживание у кассы #0 в 389.68502114499535
# Студент 14 покинул кассу #0 в 399.68502114499535
# Студент 14 обслуживался 0:22
# Студент 3 покинул кассу #1 в 411.60180861824404
# Студент 3 обслуживался 5:33
# Студент 16 направился к hot
# Студент 17 направился к hot
# LOLEL
# Студент 18 направился к cold
# Студент 18 начал обслуживание у cold_station в 426.9085006434819
# 18 student's cold time: 66
# Студент 4 покинул hot_station в 441.60180861824404
# Студент 4 начал обслуживание у drinks_station  в 441.60180861824404
# drinks time: 11
# Студент 5 начал обслуживание у hot_station в 441.60180861824404
# hot time: 113
# Студент 4 покинул drinks_station в 452.60180861824404
# [0, 0, 0]
# Студент 4 прибыл к кассе #0 в 452.60180861824404
# Студент 4 начал обслуживание у кассы #0 в 452.60180861824404
# Студент 19 направился к hot
# Студент 20 направился к hot
# Студент 21 направился к hot
# Студент 18 покинул cold_station в 492.9085006434819
# Студент 18 начал обслуживание у drinks_station  в 492.9085006434819
# drinks time: 13
# Студент 4 покинул кассу #0 в 499.60180861824404
# Студент 4 обслуживался 6:30
# Студент 18 покинул drinks_station в 505.9085006434819
# [0, 0, 0]
# Студент 18 прибыл к кассе #0 в 505.9085006434819
# Студент 18 начал обслуживание у кассы #0 в 505.9085006434819
# Студент 22 направился к hot
# Студент 23 направился к hot
# Студент 18 покинул кассу #0 в 525.9085006434818
# Студент 18 обслуживался 1:38
# Студент 5 покинул hot_station в 554.601808618244
# Студент 5 начал обслуживание у drinks_station  в 554.601808618244
# drinks time: 9
# Студент 6 начал обслуживание у hot_station в 554.601808618244
# hot time: 113
# Студент 5 покинул drinks_station в 563.601808618244
# [0, 0, 0]
# Студент 5 прибыл к кассе #0 в 563.601808618244
# Студент 5 начал обслуживание у кассы #0 в 563.601808618244
# Студент 24 направился к hot
# Студент 25 направился к hot
# Студент 5 покинул кассу #0 в 604.601808618244
# Студент 5 обслуживался 8:15
# Студент 26 направился к hot
# Студент 27 направился к hot
# Студент 28 направился к hot
# Студент 6 покинул hot_station в 667.601808618244
# Студент 6 начал обслуживание у drinks_station  в 667.601808618244
# drinks time: 5
# Студент 7 начал обслуживание у hot_station в 667.601808618244
# hot time: 64
# Студент 29 направился к hot
# Студент 30 направился к hot
# Студент 6 покинул drinks_station в 672.601808618244
# [0, 0, 0]
# Студент 6 прибыл к кассе #0 в 672.601808618244
# Студент 6 начал обслуживание у кассы #0 в 672.601808618244
# Студент 6 покинул кассу #0 в 704.601808618244
# Студент 6 обслуживался 9:50
# Студент 31 направился к hot
# Студент 32 направился к hot
# Студент 33 направился к hot
# Студент 7 покинул hot_station в 731.601808618244
# Студент 7 начал обслуживание у drinks_station  в 731.601808618244
# drinks time: 8
# Студент 8 начал обслуживание у hot_station в 731.601808618244
# hot time: 88
# Студент 7 покинул drinks_station в 739.601808618244
# [0, 0, 0]
# Студент 7 прибыл к кассе #0 в 739.601808618244
# Студент 7 начал обслуживание у кассы #0 в 739.601808618244
# Студент 7 покинул кассу #0 в 786.601808618244
# Студент 7 обслуживался 10:28
# Студент 8 покинул hot_station в 819.601808618244
# Студент 8 начал обслуживание у drinks_station  в 819.601808618244
# drinks time: 11
# Студент 9 начал обслуживание у hot_station в 819.601808618244
# hot time: 97
# Студент 34 направился к hot
# Студент 35 направился к hot
# Студент 8 покинул drinks_station в 830.601808618244
# [0, 0, 0]
# Студент 8 прибыл к кассе #0 в 830.601808618244
# Студент 8 начал обслуживание у кассы #0 в 830.601808618244
# LOLEL
# Студент 36 направился к cold
# Студент 36 начал обслуживание у cold_station в 866.7956869648427
# 36 student's cold time: 86
# Студент 37 направился к hot
# LOLEL
# Студент 38 направился к cold
# Студент 8 покинул кассу #0 в 876.601808618244
# Студент 8 обслуживался 11:45
# Студент 39 направился к hot
# Студент 40 направился к hot
# LOLEL
# Студент 41 направился к cold
# Студент 42 направился к hot
# Студент 9 покинул hot_station в 916.601808618244
# Студент 9 начал обслуживание у drinks_station  в 916.601808618244
# drinks time: 18
# Студент 10 начал обслуживание у hot_station в 916.601808618244
# hot time: 119
# Студент 9 покинул drinks_station в 934.601808618244
# [0, 0, 0]
# Студент 9 прибыл к кассе #0 в 934.601808618244
# Студент 9 начал обслуживание у кассы #0 в 934.601808618244
# Студент 43 направился к hot
# Студент 44 направился к hot
# Студент 36 покинул cold_station в 952.7956869648427
# Студент 36 начал обслуживание у drinks_station  в 952.7956869648427
# drinks time: 19
# Студент 38 начал обслуживание у cold_station в 952.7956869648427
# 38 student's cold time: 45
# Студент 45 направился к hot
# Студент 46 направился к hot
# Студент 47 направился к hot
# Студент 48 направился к hot
# Студент 49 направился к hot
# Студент 50 направился к hot
# Студент 51 направился к hot
# Студент 52 направился к hot
# Студент 9 покинул кассу #0 в 965.601808618244
# Студент 9 обслуживался 13:13
# Студент 36 покинул drinks_station в 971.7956869648427
# [0, 0, 0]
# Студент 36 прибыл к кассе #0 в 971.7956869648427
# Студент 36 начал обслуживание у кассы #0 в 971.7956869648427
# Студент 36 покинул кассу #0 в 985.7956869648427
# Студент 36 обслуживался 1:59
# Студент 38 покинул cold_station в 997.7956869648427
# Студент 38 начал обслуживание у drinks_station  в 997.7956869648427
# drinks time: 20
# Студент 41 начал обслуживание у cold_station в 997.7956869648427
# 41 student's cold time: 42
# Студент 38 покинул drinks_station в 1017.7956869648427
# [0, 0, 0]
# Студент 38 прибыл к кассе #0 в 1017.7956869648427
# Студент 38 начал обслуживание у кассы #0 в 1017.7956869648427
# Студент 53 направился к hot
# Студент 38 покинул кассу #0 в 1033.7956869648428
# Студент 38 обслуживался 2:38
# Студент 10 покинул hot_station в 1035.601808618244
# Студент 10 начал обслуживание у drinks_station  в 1035.601808618244
# drinks time: 19
# Студент 13 начал обслуживание у hot_station в 1035.601808618244
# hot time: 56
# Студент 41 покинул cold_station в 1039.7956869648428
# Студент 41 начал обслуживание у drinks_station  в 1039.7956869648428
# drinks time: 8
# LOLEL
# Студент 54 направился к cold
# Студент 54 начал обслуживание у cold_station в 1045.9764552982128
# 54 student's cold time: 45
# Студент 41 покинул drinks_station в 1047.7956869648428
# [0, 0, 0]
# Студент 41 прибыл к кассе #0 в 1047.7956869648428
# Студент 41 начал обслуживание у кассы #0 в 1047.7956869648428
# Студент 10 покинул drinks_station в 1054.601808618244
# [1, 0, 0]
# Студент 10 прибыл к кассе #1 в 1054.601808618244
# Студент 10 начал обслуживание у кассы #1 в 1054.601808618244
# Студент 55 направился к hot
# Студент 41 покинул кассу #0 в 1058.7956869648428
# Студент 41 обслуживался 2:23
# LOLEL
# Студент 56 направился к cold
# Студент 57 направился к hot
# Студент 10 покинул кассу #1 в 1090.601808618244
# Студент 10 обслуживался 14:01
# Студент 54 покинул cold_station в 1090.9764552982128
# Студент 54 начал обслуживание у drinks_station  в 1090.9764552982128
# drinks time: 6
# Студент 56 начал обслуживание у cold_station в 1090.9764552982128
# 56 student's cold time: 64
# Студент 13 покинул hot_station в 1091.601808618244
# Студент 13 начал обслуживание у drinks_station  в 1091.601808618244
# drinks time: 7
# Студент 15 начал обслуживание у hot_station в 1091.601808618244
# hot time: 71
# Студент 54 покинул drinks_station в 1096.9764552982128
# [0, 0, 0]
# Студент 54 прибыл к кассе #0 в 1096.9764552982128
# Студент 54 начал обслуживание у кассы #0 в 1096.9764552982128
# Студент 13 покинул drinks_station в 1098.601808618244
# [1, 0, 0]
# Студент 13 прибыл к кассе #1 в 1098.601808618244
# Студент 13 начал обслуживание у кассы #1 в 1098.601808618244
# Студент 54 покинул кассу #0 в 1114.9764552982128
# Студент 54 обслуживался 1:09
# Студент 58 направился к hot
# Студент 13 покинул кассу #1 в 1144.601808618244
# Студент 13 обслуживался 12:46
# LOLEL
# Студент 59 направился к drinks
# Студент 59 начал обслуживание у drinks_station  в 1151.3807297849676
# drinks time: 13
# Студент 56 покинул cold_station в 1154.9764552982128
# Студент 56 начал обслуживание у drinks_station  в 1154.9764552982128
# drinks time: 14
# Студент 15 покинул hot_station в 1162.601808618244
# Студент 15 начал обслуживание у drinks_station  в 1162.601808618244
# drinks time: 20
# Студент 16 начал обслуживание у hot_station в 1162.601808618244
# hot time: 74
# Студент 59 покинул drinks_station в 1164.3807297849676
# [0, 0, 0]
# Студент 59 прибыл к кассе #0 в 1164.3807297849676
# Студент 59 начал обслуживание у кассы #0 в 1164.3807297849676
# Студент 60 направился к hot
# Студент 61 направился к hot
# Студент 56 покинул drinks_station в 1168.9764552982128
# [1, 0, 0]
# Студент 56 прибыл к кассе #1 в 1168.9764552982128
# Студент 56 начал обслуживание у кассы #1 в 1168.9764552982128
# Студент 59 покинул кассу #0 в 1172.3807297849676
# Студент 59 обслуживался 0:21
# Студент 62 направился к hot
# Студент 56 покинул кассу #1 в 1181.9764552982128
# Студент 56 обслуживался 1:45
# Студент 15 покинул drinks_station в 1182.601808618244
# [0, 0, 0]
# Студент 15 прибыл к кассе #0 в 1182.601808618244
# Студент 15 начал обслуживание у кассы #0 в 1182.601808618244
# Студент 15 покинул кассу #0 в 1221.601808618244
# Студент 15 обслуживался 13:58
# Студент 16 покинул hot_station в 1236.601808618244
# Студент 16 начал обслуживание у drinks_station  в 1236.601808618244
# drinks time: 6
# Студент 17 начал обслуживание у hot_station в 1236.601808618244
# hot time: 60
# Студент 16 покинул drinks_station в 1242.601808618244
# [0, 0, 0]
# Студент 16 прибыл к кассе #0 в 1242.601808618244
# Студент 16 начал обслуживание у кассы #0 в 1242.601808618244
# LOLEL
# Студент 63 направился к cold
# Студент 63 начал обслуживание у cold_station в 1254.3120140671658
# 63 student's cold time: 55
# Студент 64 направился к hot
# Студент 65 направился к hot
# Студент 66 направился к hot
# Студент 67 направился к hot
# Студент 16 покинул кассу #0 в 1280.601808618244
# Студент 16 обслуживался 14:13
# Студент 68 направился к hot
# Студент 69 направился к hot
# Студент 70 направился к hot
# Студент 17 покинул hot_station в 1296.601808618244
# Студент 17 начал обслуживание у drinks_station  в 1296.601808618244
# drinks time: 14
# Студент 19 начал обслуживание у hot_station в 1296.601808618244
# hot time: 90
# Студент 71 направился к hot
# Студент 63 покинул cold_station в 1309.3120140671658
# Студент 63 начал обслуживание у drinks_station  в 1309.3120140671658
# drinks time: 8
# Студент 17 покинул drinks_station в 1310.601808618244
# [0, 0, 0]
# Студент 17 прибыл к кассе #0 в 1310.601808618244
# Студент 17 начал обслуживание у кассы #0 в 1310.601808618244
# Студент 63 покинул drinks_station в 1317.3120140671658
# [1, 0, 0]
# Студент 63 прибыл к кассе #1 в 1317.3120140671658
# Студент 63 начал обслуживание у кассы #1 в 1317.3120140671658
# Студент 63 покинул кассу #1 в 1328.3120140671658
# Студент 63 обслуживался 1:14
# Студент 72 направился к hot
# Студент 73 направился к hot
# Студент 17 покинул кассу #0 в 1343.601808618244
# Студент 17 обслуживался 15:16
# Студент 74 направился к hot
# Студент 75 направился к hot
# Студент 76 направился к hot
# Студент 77 направился к hot
# Студент 78 направился к hot
# LOLEL
# Студент 79 направился к cold
# Студент 79 начал обслуживание у cold_station в 1384.5696216830638
# 79 student's cold time: 36
# Студент 19 покинул hot_station в 1386.601808618244
# Студент 19 начал обслуживание у drinks_station  в 1386.601808618244
# drinks time: 13
# Студент 20 начал обслуживание у hot_station в 1386.601808618244
# hot time: 63
# Студент 19 покинул drinks_station в 1399.601808618244
# [0, 0, 0]
# Студент 19 прибыл к кассе #0 в 1399.601808618244
# Студент 19 начал обслуживание у кассы #0 в 1399.601808618244
# Студент 79 покинул cold_station в 1420.5696216830638
# Студент 79 начал обслуживание у drinks_station  в 1420.5696216830638
# drinks time: 9
# Студент 19 покинул кассу #0 в 1426.601808618244
# Студент 19 обслуживался 15:50
# Студент 79 покинул drinks_station в 1429.5696216830638
# [0, 0, 0]
# Студент 79 прибыл к кассе #0 в 1429.5696216830638
# Студент 79 начал обслуживание у кассы #0 в 1429.5696216830638
# Студент 80 направился к hot
# Студент 81 направился к hot
# Студент 82 направился к hot
# Студент 79 покинул кассу #0 в 1443.5696216830638
# Студент 79 обслуживался 0:59
# Студент 20 покинул hot_station в 1449.601808618244
# Студент 20 начал обслуживание у drinks_station  в 1449.601808618244
# drinks time: 6
# Студент 21 начал обслуживание у hot_station в 1449.601808618244
# hot time: 104
# Студент 20 покинул drinks_station в 1455.601808618244
# [0, 0, 0]
# Студент 20 прибыл к кассе #0 в 1455.601808618244
# Студент 20 начал обслуживание у кассы #0 в 1455.601808618244
# Студент 20 покинул кассу #0 в 1497.601808618244
# Студент 20 обслуживался 17:01
# Студент 83 направился к hot
# Студент 84 направился к hot
# Студент 85 направился к hot
# Студент 86 направился к hot
# Студент 87 направился к hot
# Студент 88 направился к hot
# Студент 89 направился к hot
# Студент 90 направился к hot
# Студент 91 направился к hot
# Студент 92 направился к hot
# Студент 93 направился к hot
# Студент 94 направился к hot
# Студент 95 направился к hot
# Студент 96 направился к hot
# Студент 21 покинул hot_station в 1553.601808618244
# Студент 21 начал обслуживание у drinks_station  в 1553.601808618244
# drinks time: 16
# Студент 22 начал обслуживание у hot_station в 1553.601808618244
# hot time: 102
# Студент 21 покинул drinks_station в 1569.601808618244
# [0, 0, 0]
# Студент 21 прибыл к кассе #0 в 1569.601808618244
# Студент 21 начал обслуживание у кассы #0 в 1569.601808618244
# Студент 21 покинул кассу #0 в 1606.601808618244
# Студент 21 обслуживался 18:50
# Студент 22 покинул hot_station в 1655.601808618244
# Студент 22 начал обслуживание у drinks_station  в 1655.601808618244
# drinks time: 9
# Студент 23 начал обслуживание у hot_station в 1655.601808618244
# hot time: 70
# Студент 97 направился к hot
# Студент 98 направился к hot
# LOLEL
# Студент 99 направился к cold
# Студент 99 начал обслуживание у cold_station в 1659.989489541207
# 99 student's cold time: 81
# Студент 100 направился к hot
# Студент 101 направился к hot
# Студент 102 направился к hot
# Студент 22 покинул drinks_station в 1664.601808618244
# [0, 0, 0]
# Студент 22 прибыл к кассе #0 в 1664.601808618244
# Студент 22 начал обслуживание у кассы #0 в 1664.601808618244
# Студент 22 покинул кассу #0 в 1709.601808618244
# Студент 22 обслуживался 20:02
# Студент 103 направился к hot
# LOLEL
# Студент 104 направился к cold
# Студент 105 направился к hot
# Студент 23 покинул hot_station в 1725.601808618244
# Студент 23 начал обслуживание у drinks_station  в 1725.601808618244
# drinks time: 14
# Студент 24 начал обслуживание у hot_station в 1725.601808618244
# hot time: 78
# Студент 23 покинул drinks_station в 1739.601808618244
# [0, 0, 0]
# Студент 23 прибыл к кассе #0 в 1739.601808618244
# Студент 23 начал обслуживание у кассы #0 в 1739.601808618244
# Студент 99 покинул cold_station в 1740.989489541207
# Студент 99 начал обслуживание у drinks_station  в 1740.989489541207
# drinks time: 11
# Студент 104 начал обслуживание у cold_station в 1740.989489541207
# 104 student's cold time: 51
# Студент 99 покинул drinks_station в 1751.989489541207
# [1, 0, 0]
# Студент 99 прибыл к кассе #1 в 1751.989489541207
# Студент 99 начал обслуживание у кассы #1 в 1751.989489541207
# Студент 106 направился к hot
# Студент 107 направился к hot
# Студент 108 направился к hot
# Студент 23 покинул кассу #0 в 1770.601808618244
# Студент 23 обслуживался 21:03
# Студент 99 покинул кассу #1 в 1774.989489541207
# Студент 99 обслуживался 1:55
# Студент 104 покинул cold_station в 1791.989489541207
# Студент 104 начал обслуживание у drinks_station  в 1791.989489541207
# drinks time: 15
# Студент 24 покинул hot_station в 1803.601808618244
# Студент 24 начал обслуживание у drinks_station  в 1803.601808618244
# drinks time: 8
# Студент 25 начал обслуживание у hot_station в 1803.601808618244
# hot time: 72
# Студент 104 покинул drinks_station в 1806.989489541207
# [0, 0, 0]
# Студент 104 прибыл к кассе #0 в 1806.989489541207
# Студент 104 начал обслуживание у кассы #0 в 1806.989489541207
# Студент 24 покинул drinks_station в 1811.601808618244
# [1, 0, 0]
# Студент 24 прибыл к кассе #1 в 1811.601808618244
# Студент 24 начал обслуживание у кассы #1 в 1811.601808618244
# Студент 104 покинул кассу #0 в 1820.989489541207
# Студент 104 обслуживался 1:50
# Студент 24 покинул кассу #1 в 1838.601808618244
# Студент 24 обслуживался 21:03
# Студент 109 направился к hot
# Студент 110 направился к hot
# Студент 111 направился к hot
# Студент 112 направился к hot
# Студент 25 покинул hot_station в 1875.601808618244
# Студент 25 начал обслуживание у drinks_station  в 1875.601808618244
# drinks time: 8
# Студент 26 начал обслуживание у hot_station в 1875.601808618244
# hot time: 74
# Студент 113 направился к hot
# Студент 25 покинул drinks_station в 1883.601808618244
# [0, 0, 0]
# Студент 25 прибыл к кассе #0 в 1883.601808618244
# Студент 25 начал обслуживание у кассы #0 в 1883.601808618244
# LOLEL
# Студент 114 направился к cold
# Студент 115 направился к hot
# Студент 116 направился к hot
# Студент 114 начал обслуживание у cold_station в 1898.0428392510642
# 114 student's cold time: 57
# Студент 25 покинул кассу #0 в 1929.601808618244
# Студент 25 обслуживался 22:34
# Студент 117 направился к hot
# Студент 118 направился к hot
# Студент 119 направился к hot
# LOLEL
# Студент 120 направился к cold
# Студент 26 покинул hot_station в 1949.601808618244
# Студент 26 начал обслуживание у drinks_station  в 1949.601808618244
# drinks time: 14
# Студент 27 начал обслуживание у hot_station в 1949.601808618244
# hot time: 102
# Студент 114 покинул cold_station в 1955.0428392510642
# Студент 114 начал обслуживание у drinks_station  в 1955.0428392510642
# drinks time: 17
# Студент 120 начал обслуживание у cold_station в 1955.0428392510642
# 120 student's cold time: 48
# Студент 26 покинул drinks_station в 1963.601808618244
# [0, 0, 0]
# Студент 26 прибыл к кассе #0 в 1963.601808618244
# Студент 26 начал обслуживание у кассы #0 в 1963.601808618244
# Студент 114 покинул drinks_station в 1972.0428392510642
# [1, 0, 0]
# Студент 114 прибыл к кассе #1 в 1972.0428392510642
# Студент 114 начал обслуживание у кассы #1 в 1972.0428392510642
# Студент 114 покинул кассу #1 в 1988.0428392510642
# Студент 114 обслуживался 1:30
# Студент 26 покинул кассу #0 в 2001.601808618244
# Студент 26 обслуживался 22:47
# Студент 120 покинул cold_station в 2003.0428392510642
# Студент 120 начал обслуживание у drinks_station  в 2003.0428392510642
# drinks time: 9
# Студент 121 направился к hot
# hot time: 81
# Студент 29 покинул drinks_station в 2273.601808618244
# [0, 0, 0]
# Студент 29 прибыл к кассе #0 в 2273.601808618244
# Студент 29 начал обслуживание у кассы #0 в 2273.601808618244
# Студент 137 направился к hot
# Студент 29 покинул кассу #0 в 2318.601808618244
# Студент 29 обслуживался 27:28
# Студент 30 покинул hot_station в 2335.601808618244
# Студент 30 начал обслуживание у drinks_station  в 2335.601808618244
# drinks time: 15
# Студент 31 начал обслуживание у hot_station в 2335.601808618244
# hot time: 114
# LOLEL
# Студент 138 направился к cold
# Студент 139 направился к hot
# Студент 140 направился к hot
# Студент 138 начал обслуживание у cold_station в 2341.761128568824
# 138 student's cold time: 46
# Студент 30 покинул drinks_station в 2350.601808618244
# [0, 0, 0]
# Студент 30 прибыл к кассе #0 в 2350.601808618244
# Студент 30 начал обслуживание у кассы #0 в 2350.601808618244
# Студент 141 направился к hot
# Студент 142 направился к hot
# Студент 143 направился к hot
# Студент 144 направился к hot
# Студент 30 покинул кассу #0 в 2381.601808618244
# Студент 30 обслуживался 28:31
# Студент 138 покинул cold_station в 2387.761128568824
# Студент 138 начал обслуживание у drinks_station  в 2387.761128568824
# drinks time: 15
# Студент 138 покинул drinks_station в 2402.761128568824
# [0, 0, 0]
# Студент 138 прибыл к кассе #0 в 2402.761128568824
# Студент 138 начал обслуживание у кассы #0 в 2402.761128568824
# Студент 145 направился к hot
# Студент 146 направился к hot
# Студент 147 направился к hot
# Студент 148 направился к hot
# Студент 138 покинул кассу #0 в 2417.761128568824
# Студент 138 обслуживался 1:16
# LOLEL
# Студент 149 направился к cold
# Студент 149 начал обслуживание у cold_station в 2431.421147901298
# 149 student's cold time: 54
# LOLEL
# Студент 150 направился к cold
# Студент 151 направился к hot
# Студент 152 направился к hot
# LOLEL
# Студент 153 направился к cold
# LOLEL
# Студент 154 направился к cold
# Студент 155 направился к hot
# Студент 156 направился к hot
# LOLEL
# Студент 157 направился к cold
# Студент 31 покинул hot_station в 2449.601808618244
# Студент 31 начал обслуживание у drinks_station  в 2449.601808618244
# drinks time: 20
# Студент 32 начал обслуживание у hot_station в 2449.601808618244
# hot time: 84
# Студент 31 покинул drinks_station в 2469.601808618244
# [0, 0, 0]
# Студент 31 прибыл к кассе #0 в 2469.601808618244
# Студент 31 начал обслуживание у кассы #0 в 2469.601808618244
# Студент 158 направился к hot
# Студент 149 покинул cold_station в 2485.421147901298
# Студент 149 начал обслуживание у drinks_station  в 2485.421147901298
# drinks time: 17
# Студент 150 начал обслуживание у cold_station в 2485.421147901298
# 150 student's cold time: 40
# Студент 159 направился к hot
# LOLEL
# Студент 160 направился к cold
# Студент 161 направился к hot
# Студент 162 направился к hot
# Студент 149 покинул drinks_station в 2502.421147901298
# [1, 0, 0]
# Студент 149 прибыл к кассе #1 в 2502.421147901298
# Студент 149 начал обслуживание у кассы #1 в 2502.421147901298
# Студент 31 покинул кассу #0 в 2508.601808618244
# Студент 31 обслуживался 29:54
# Студент 150 покинул cold_station в 2525.421147901298
# Студент 150 начал обслуживание у drinks_station  в 2525.421147901298
# drinks time: 7
# Студент 153 начал обслуживание у cold_station в 2525.421147901298
# 153 student's cold time: 57
# Студент 149 покинул кассу #1 в 2526.421147901298
# Студент 149 обслуживался 1:35
# Студент 150 покинул drinks_station в 2532.421147901298
# [0, 0, 0]
# Студент 150 прибыл к кассе #0 в 2532.421147901298
# Студент 150 начал обслуживание у кассы #0 в 2532.421147901298
# Студент 32 покинул hot_station в 2533.601808618244
# Студент 32 начал обслуживание у drinks_station  в 2533.601808618244
# drinks time: 19
# Студент 33 начал обслуживание у hot_station в 2533.601808618244
# hot time: 56
# Студент 32 покинул drinks_station в 2552.601808618244
# [1, 0, 0]
# Студент 32 прибыл к кассе #1 в 2552.601808618244
# Студент 32 начал обслуживание у кассы #1 в 2552.601808618244
# Студент 150 покинул кассу #0 в 2554.421147901298
# Студент 150 обслуживался 2:01
# Студент 153 покинул cold_station в 2582.421147901298
# Студент 153 начал обслуживание у drinks_station  в 2582.421147901298
# drinks time: 17
# Студент 154 начал обслуживание у cold_station в 2582.421147901298
# 154 student's cold time: 43
# Студент 33 покинул hot_station в 2589.601808618244
# Студент 33 начал обслуживание у drinks_station  в 2589.601808618244
# drinks time: 15
# Студент 34 начал обслуживание у hot_station в 2589.601808618244
# hot time: 98
# Студент 32 покинул кассу #1 в 2591.601808618244
# Студент 32 обслуживался 31:17
# Студент 153 покинул drinks_station в 2599.421147901298
# [0, 0, 0]
# Студент 153 прибыл к кассе #0 в 2599.421147901298
# Студент 153 начал обслуживание у кассы #0 в 2599.421147901298
# Студент 33 покинул drinks_station в 2604.601808618244
# [1, 0, 0]
# Студент 33 прибыл к кассе #1 в 2604.601808618244
# Студент 33 начал обслуживание у кассы #1 в 2604.601808618244
# Студент 163 направился к hot
# Студент 164 направился к hot
# Студент 153 покинул кассу #0 в 2613.421147901298
# Студент 153 обслуживался 3:00
# Студент 154 покинул cold_station в 2625.421147901298
# Студент 154 начал обслуживание у drinks_station  в 2625.421147901298
# drinks time: 5
# Студент 157 начал обслуживание у cold_station в 2625.421147901298
# 157 student's cold time: 64
# Студент 154 покинул drinks_station в 2630.421147901298
# [0, 1, 0]
# Студент 154 прибыл к кассе #0 в 2630.421147901298
# Студент 154 начал обслуживание у кассы #0 в 2630.421147901298
# Студент 33 покинул кассу #1 в 2639.601808618244
# Студент 33 обслуживался 32:05
# Студент 154 покинул кассу #0 в 2652.421147901298
# Студент 154 обслуживался 3:38
# Студент 165 направился к hot
# Студент 166 направился к hot
# Студент 167 направился к hot
# Студент 168 направился к hot
# Студент 169 направился к hot
# Студент 170 направился к hot
# Студент 171 направился к hot
# Студент 172 направился к hot
# Студент 173 направился к hot
# Студент 174 направился к hot
# Студент 175 направился к hot
# Студент 34 покинул hot_station в 2687.601808618244
# Студент 34 начал обслуживание у drinks_station  в 2687.601808618244
# drinks time: 8
# Студент 35 начал обслуживание у hot_station в 2687.601808618244
# hot time: 89
# Студент 157 покинул cold_station в 2689.421147901298
# Студент 157 начал обслуживание у drinks_station  в 2689.421147901298
# drinks time: 5
# Студент 160 начал обслуживание у cold_station в 2689.421147901298
# 160 student's cold time: 66
# Студент 157 покинул drinks_station в 2694.421147901298
# [0, 0, 0]
# Студент 157 прибыл к кассе #0 в 2694.421147901298
# Студент 157 начал обслуживание у кассы #0 в 2694.421147901298
# Студент 34 покинул drinks_station в 2695.601808618244
# [1, 0, 0]
# Студент 34 прибыл к кассе #1 в 2695.601808618244
# Студент 34 начал обслуживание у кассы #1 в 2695.601808618244
# Студент 157 покинул кассу #0 в 2706.421147901298
# Студент 157 обслуживался 4:17
# LOLEL
# Студент 176 направился к cold
# Студент 177 направился к hot
# Студент 178 направился к hot
# LOLEL
# Студент 179 направился к cold
# Студент 180 направился к hot
# Студент 34 покинул кассу #1 в 2729.601808618244
# Студент 34 обслуживался 31:48
# Студент 160 покинул cold_station в 2755.421147901298
# Студент 160 начал обслуживание у drinks_station  в 2755.421147901298
# drinks time: 8
# Студент 176 начал обслуживание у cold_station в 2755.421147901298
# 176 student's cold time: 80
# Студент 160 покинул drinks_station в 2763.421147901298
# [0, 0, 0]
# Студент 160 прибыл к кассе #0 в 2763.421147901298
# Студент 160 начал обслуживание у кассы #0 в 2763.421147901298
# Студент 181 направился к hot
# Студент 35 покинул hot_station в 2776.601808618244
# Студент 35 начал обслуживание у drinks_station  в 2776.601808618244
# drinks time: 15
# Студент 37 начал обслуживание у hot_station в 2776.601808618244
# hot time: 103
# Студент 182 направился к hot
# Студент 160 покинул кассу #0 в 2787.421147901298
# Студент 160 обслуживался 5:00
# Студент 35 покинул drinks_station в 2791.601808618244
# [0, 0, 0]
# Студент 35 прибыл к кассе #0 в 2791.601808618244
# Студент 35 начал обслуживание у кассы #0 в 2791.601808618244
# Студент 35 покинул кассу #0 в 2819.601808618244
# Студент 35 обслуживался 33:18
# Студент 176 покинул cold_station в 2835.421147901298
# Студент 176 начал обслуживание у drinks_station  в 2835.421147901298
# drinks time: 19
# Студент 179 начал обслуживание у cold_station в 2835.421147901298
# 179 student's cold time: 39
# Студент 176 покинул drinks_station в 2854.421147901298
# [0, 0, 0]
# Студент 176 прибыл к кассе #0 в 2854.421147901298
# Студент 176 начал обслуживание у кассы #0 в 2854.421147901298
# Студент 176 покинул кассу #0 в 2869.421147901298
# Студент 176 обслуживался 2:35
# Студент 179 покинул cold_station в 2874.421147901298
# Студент 179 начал обслуживание у drinks_station  в 2874.421147901298
# drinks time: 10
# Студент 183 направился к hot
# LOLEL
# Студент 184 направился к cold
# Студент 184 начал обслуживание у cold_station в 2877.5872052577224
# 184 student's cold time: 79
# Студент 37 покинул hot_station в 2879.601808618244
# Студент 37 начал обслуживание у drinks_station  в 2879.601808618244
# drinks time: 19
# Студент 39 начал обслуживание у hot_station в 2879.601808618244
# hot time: 84
# Студент 179 покинул drinks_station в 2884.421147901298
# [0, 0, 0]
# Студент 179 прибыл к кассе #0 в 2884.421147901298
# Студент 179 начал обслуживание у кассы #0 в 2884.421147901298
# Студент 40 покинул кассу #0 в 3115.601808618244
# Студент 40 обслуживался 36:40
# Студент 197 покинул drinks_station в 3122.7226886940384
# [0, 1, 0]
# Студент 197 прибыл к кассе #0 в 3122.7226886940384
# Студент 197 начал обслуживание у кассы #0 в 3122.7226886940384
# Студент 188 покинул кассу #1 в 3124.5872052577224
# Студент 188 обслуживался 2:42
# Студент 197 покинул кассу #0 в 3128.7226886940384
# Студент 197 обслуживался 0:16
# Студент 198 направился к hot
# Студент 42 покинул hot_station в 3160.601808618244
# Студент 42 начал обслуживание у drinks_station  в 3160.601808618244
# drinks time: 14
# Студент 43 начал обслуживание у hot_station в 3160.601808618244
# hot time: 74
# Студент 199 направился к hot
# Студент 42 покинул drinks_station в 3174.601808618244
# [0, 0, 0]
# Студент 42 прибыл к кассе #0 в 3174.601808618244
# Студент 42 начал обслуживание у кассы #0 в 3174.601808618244
# LOLEL
# Студент 200 направился к drinks
# Студент 200 начал обслуживание у drinks_station  в 3179.263291289152
# Студент 201 направился к hot
# drinks time: 9
# Студент 200 покинул drinks_station в 3188.263291289152
# [1, 0, 0]
# Студент 200 прибыл к кассе #1 в 3188.263291289152
# Студент 200 начал обслуживание у кассы #1 в 3188.263291289152
# LOLEL
# Студент 202 направился к cold
# Студент 203 направился к hot
# Студент 204 направился к hot
# Студент 202 начал обслуживание у cold_station в 3188.8823167161318
# 202 student's cold time: 58
# Студент 200 покинул кассу #1 в 3198.263291289152
# Студент 200 обслуживался 0:19
# LOLEL
# Студент 205 направился к cold
# Студент 206 направился к hot
# Студент 42 покинул кассу #0 в 3213.601808618244
# Студент 42 обслуживался 38:18
# Студент 43 покинул hot_station в 3234.601808618244
# Студент 43 начал обслуживание у drinks_station  в 3234.601808618244
# drinks time: 7
# Студент 44 начал обслуживание у hot_station в 3234.601808618244
# hot time: 56
# Студент 43 покинул drinks_station в 3241.601808618244
# [0, 0, 0]
# Студент 43 прибыл к кассе #0 в 3241.601808618244
# Студент 43 начал обслуживание у кассы #0 в 3241.601808618244
# Студент 202 покинул cold_station в 3246.8823167161318
# Студент 202 начал обслуживание у drinks_station  в 3246.8823167161318
# drinks time: 9
# Студент 205 начал обслуживание у cold_station в 3246.8823167161318
# 205 student's cold time: 90
# Студент 202 покинул drinks_station в 3255.8823167161318
# [1, 0, 0]
# Студент 202 прибыл к кассе #1 в 3255.8823167161318
# Студент 202 начал обслуживание у кассы #1 в 3255.8823167161318
# Студент 207 направился к hot
# Студент 208 направился к hot
# Студент 202 покинул кассу #1 в 3274.8823167161318
# Студент 202 обслуживался 1:26
# Студент 43 покинул кассу #0 в 3279.601808618244
# Студент 43 обслуживался 39:01
# Студент 44 покинул hot_station в 3290.601808618244
# Студент 44 начал обслуживание у drinks_station  в 3290.601808618244
# drinks time: 17
# Студент 45 начал обслуживание у hot_station в 3290.601808618244
# hot time: 106
# Студент 209 направился к hot
# Студент 210 направился к hot
# Студент 211 направился к hot
# Студент 44 покинул drinks_station в 3307.601808618244
# [0, 0, 0]
# Студент 51 начал обслуживание у hot_station в 3888.601808618244
# hot time: 80
# Студент 50 покинул drinks_station в 3896.601808618244
# [0, 0, 0]
# Студент 50 прибыл к кассе #0 в 3896.601808618244
# Студент 50 начал обслуживание у кассы #0 в 3896.601808618244
# Студент 244 направился к hot
# Студент 245 направился к hot
# Студент 50 покинул кассу #0 в 3940.601808618244
# Студент 50 обслуживался 49:45
# Студент 246 направился к hot
# LOLEL
# Студент 247 направился к cold
# Студент 248 направился к hot
# Студент 249 направился к hot
# Студент 247 начал обслуживание у cold_station в 3961.853079318137
# 247 student's cold time: 56
# Студент 51 покинул hot_station в 3968.601808618244
# Студент 51 начал обслуживание у drinks_station  в 3968.601808618244
# drinks time: 20
# Студент 52 начал обслуживание у hot_station в 3968.601808618244
# hot time: 108
# Студент 51 покинул drinks_station в 3988.601808618244
# [0, 0, 0]
# Студент 51 прибыл к кассе #0 в 3988.601808618244
# Студент 51 начал обслуживание у кассы #0 в 3988.601808618244
# Студент 250 направился к hot
# Студент 251 направился к hot
# Студент 252 направился к hot
# Студент 253 направился к hot
# Студент 254 направился к hot
# Студент 255 направился к hot
# Студент 256 направился к hot
# Студент 257 направился к hot
# Студент 247 покинул cold_station в 4017.853079318137
# Студент 247 начал обслуживание у drinks_station  в 4017.853079318137
# drinks time: 9
# Студент 51 покинул кассу #0 в 4019.601808618244
# Студент 51 обслуживался 50:54
# Студент 247 покинул drinks_station в 4026.853079318137
# [0, 0, 0]
# Студент 247 прибыл к кассе #0 в 4026.853079318137
# Студент 247 начал обслуживание у кассы #0 в 4026.853079318137
# Студент 247 покинул кассу #0 в 4046.853079318137
# Студент 247 обслуживался 1:25
# Студент 258 направился к hot
# Студент 259 направился к hot
# Студент 52 покинул hot_station в 4076.601808618244
# Студент 52 начал обслуживание у drinks_station  в 4076.601808618244
# drinks time: 19
# Студент 53 начал обслуживание у hot_station в 4076.601808618244
# hot time: 74
# Студент 260 направился к hot
# Студент 261 направился к hot
# LOLEL
# Студент 262 направился к cold
# Студент 263 направился к hot
# Студент 262 начал обслуживание у cold_station в 4091.546454154641
# 262 student's cold time: 72
# Студент 52 покинул drinks_station в 4095.601808618244
# [0, 0, 0]
# Студент 52 прибыл к кассе #0 в 4095.601808618244
# Студент 52 начал обслуживание у кассы #0 в 4095.601808618244
# Студент 264 направился к hot
# Студент 265 направился к hot
# Студент 266 направился к hot
# LOLEL
# ...
# Студент 272 начал обслуживание у drinks_station  в 4373.546454154641
# drinks time: 14
# Студент 278 начал обслуживание у cold_station в 4373.546454154641
# 278 student's cold time: 48
# Студент 290 покинул drinks_station в 4376.412655788047
# [0, 0, 0]
# Студент 290 прибыл к кассе #0 в 4376.412655788047
# Студент 290 начал обслуживание у кассы #0 в 4376.412655788047
# Студент 290 покинул кассу #0 в 4384.412655788047
# Студент 290 обслуживался 0:25
# Студент 295 направился к hot
# Студент 296 направился к hot
# Студент 297 направился к hot
# Студент 298 направился к hot
# Студент 272 покинул drinks_station в 4387.546454154641
# Студент 360 обслуживался 1:12
# Студент 70 покинул hot_station в 5392.601808618244
# Студент 70 начал обслуживание у drinks_station  в 5392.601808618244
# drinks time: 13
# Студент 71 начал обслуживание у hot_station в 5392.601808618244
# hot time: 73

# %%
mn_hot = sum([std.delays["hot"] for std in STUDETNTS if (std.way == "hot" and std.finished)]) / len([std for std in STUDETNTS if (std.way == "hot" and std.finished)])
print_time("Mean hot delay:", mn_hot)
mx_hot = max([std.delays["hot"] for std in STUDETNTS if (std.way == "hot" and std.finished)])
print_time("Max  hot delay", mx_hot)
# Out:
# Mean hot delay: 30:38
# Max  hot delay 64:46

# %%
mn_cold = sum([std.delays["cold"] for std in STUDETNTS if (std.way == "cold" and std.finished)]) / len([std for std in STUDETNTS if (std.way == "cold" and std.finished)])
print_time("Mean cold delay:", mn_cold)
mx_cold = max([std.delays["cold"] for std in STUDETNTS if std.way == "cold" and std.finished])
print_time("Max  cold delay:", mx_cold)
# Out:
# Mean cold delay: 1:17
# Max  cold delay: 5:52

# %%
mn_cash = sum([std.delays["cash"] for std in STUDETNTS if std.finished]) / len([std for std in STUDETNTS if std.finished])
mx_cash = max([std.delays["cash"] for std in STUDETNTS if std.finished])
print_time("Mean cash delay:", mn_cash)
print_time("Max  cash delay:", mx_cash)
max([std.delays["cash"] for std in STUDETNTS if std.finished])
# Out:
# Mean cash delay: 0:00
# Max  cash delay: 0:00
# 0.0

# %%
print("Mean hot_station queue:", int(cnt.mean_hot_queue))
print("Max  hot_station queue:", cnt.max_hot_queue)
# Out:
# Mean hot_station queue: 112
# Max  hot_station queue: 241

# %%
print("Mean cold_station queue:", int(cnt.mean_cold_queue))
print("Max  cold_station queue:", cnt.max_cold_queue)
# Out:
# Mean cold_station queue: 0
# Max  cold_station queue: 5

# %%
print("Mean cashbox queue:", int(cnt.mean_cash_queue))
print("Max  cashbox queue:", cnt.max_cash_queue)
# Out:
# Mean cashbox queue: 0
# Max  cashbox queue: 1

# %%
type1 = [std for std in STUDETNTS if (std.way == "hot" and std.finished)]
type2 = [std for std in STUDETNTS if (std.way == "cold" and std.finished)]
type3 = [std for std in STUDETNTS if (std.way == "drinks" and std.finished)]
types = [type1, type2, type3]

for i in range(len(types)):
    print_time("Mean queue delay for type{0}:".format(i+1), sum([sum(std.delays.values()) for std in types[i]]) / len(types[i]))
    print_time("Max  queue delay for type{0}:".format(i+1), max([sum(std.delays.values()) for std in types[i]]))
    print()
# Out:
# Mean queue delay for type1: 30:38
# Max  queue delay for type1: 64:46
#
# Mean queue delay for type2: 1:17
# Max  queue delay for type2: 5:52
#
# Mean queue delay for type3: 0:00
# Max  queue delay for type3: 0:00

# %%
print("Mean total students:", int(cnt.mean_all))
# Out:
# Mean total students: 113

# %%
print("Max total students:", int(cnt.max_all))
# Out:
# Max total students: 245

# %%
mn_total = sum([sum(std.delays.values()) for std in STUDETNTS if std.finished]) / len([std for std in STUDETNTS if std.finished])
print_time("Mean total service time:", mn_total)
# Out:
# Mean total service time: 15:13
