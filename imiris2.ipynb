# %%
import simpy as smp
from random import expovariate, random, randint

# %%
def print_time(s, sec):
    mins = str(int(sec // 60))
    secs = int(sec %  60)
    if secs // 10 == 0:
        secs = "0" + str(secs)
    else:
        secs = str(secs)
    print(s, mins + ":" + secs)

# %%
def discrete_rv(drv):
    if sum([val[0] for val in drv]) != 1:
        raise 1
    r = random()
    s = 0
    for pair in drv:
        if (r > s) and (r < (s + pair[0])):
            return pair[1]
        s += pair[0]

# %%
CUSTOMER_DSTRB = [[0.5, 1], [0.3, 2], [0.1, 3], [0.1, 4]]
WAY_DSTRB = [[0.8, "hot"], [0.15, "cold"], [0.05, "drinks"]]
CASHBOX_NUMBER = 2
MEAN_GAP = 30
CUSTOMER_NUMBER = 0
STUDETNTS = []

# %%
def gen_group(env, canteen):
    global CUSTOMER_NUMBER, STUDETNTS
    env.process(canteen.start())
    while True:
        yield env.timeout(expovariate(1 / MEAN_GAP))
        n = discrete_rv(CUSTOMER_DSTRB)
        for i in range(n):
            std = Student(env, canteen, CUSTOMER_NUMBER)
            STUDETNTS += [std]
            env.process(std.start())
            CUSTOMER_NUMBER += 1

# %%
class Student:
    def __init__(self, env, canteen, index):
        self.env = env
        self.canteen = canteen
        self.index = index
        self.service_time = 0
        self.cashbox_time = 0
        self.delays = {"hot":0, "cold":0, "cash":0}
        self.cash_wait = 0
        self.finished = 0
    def start(self):
        self.service_time = self.env.now
        self.way = discrete_rv(WAY_DSTRB)
        print("Студент {0} направился к {1}".format(self.index, self.way))
        if self.way != "drinks":
            with self.canteen.stations[self.way][0].request() as req:
                self.canteen.stations[self.way][2] += 1
                wait = self.env.now
                yield req
                self.canteen.stations[self.way][2] -= 1
                self.delays[self.way] = self.env.now - wait
                print("Студент {0} начал обслуживание у {1}_station в {2}".format(self.index, self.way, self.env.now))
                yield self.env.process(self.canteen.stations[self.way][1](self))
                print("Студент {0} покинул {1}_station в {2}".format(self.index, self.way, self.env.now))
        
        print("Студент {0} начал обслуживание у drinks_station  в {1}".format(self.index, self.env.now))
        yield self.env.process(self.canteen.drinks_station(self))
        print("Студент {0} покинул drinks_station в {1}".format(self.index, self.env.now))
               
        cash_n, cashbox, q_len = min(self.canteen.cashboxes, key=lambda x: x[2])
        print([cbox[2] for cbox in self.canteen.cashboxes])
        print("Студент {0} прибыл к кассе #{1} в {2}".format(self.index, cash_n,  self.env.now))
        
        
        self.canteen.cashboxes[cash_n][2] += 1
        wait = self.env.now
        with cashbox.request() as cash_req:
            yield cash_req
            self.delays["cash"] = self.env.now - wait
            if (self.way == "hot"):
                print("HOT_WAY queue DELAY", self.delays["cash"])
            if (self.way == "cold"):
                print("COLD_WAY queue DELAY", self.delays["cash"])
            print("Студент {0} начал обслуживание у кассы #{1} в {2}".format(self.index, cash_n, self.env.now))
            yield self.env.process(self.canteen.cashbox(self))
            print("Студент {0} покинул кассу #{1} в {2}".format(self.index, cash_n, self.env.now))
            self.canteen.cashboxes[cash_n][2] -= 1
        self.finished = 1
        self.service_time = self.env.now - self.service_time
        print_time("Студент {0} обслуживался".format(self.index), self.service_time)

# %%
class Canteen:
    def __init__(self, env):
        self.env = env
        self.hot = smp.Resource(self.env, capacity=1)
        self.cold = smp.Resource(self.env, capacity=1)
        self.cashboxes = [[i, smp.Resource(self.env, capacity=1), 0] for i in range(CASHBOX_NUMBER)]
        self.stations = {"hot":[self.hot, self.hot_station, 0], "cold":[self.cold, self.cold_station, 0]}
    
    def hot_station(self, student):
        time = randint(50, 120)
        student.cashbox_time += randint(20, 40)
        print("hot time:", time)
        yield student.env.timeout(time)
    
    def cold_station(self, student):
        time = randint(60, 180)
        student.cashbox_time += randint(5, 15)
        print("{0} student's cold time:".format(student.index), time)
        yield student.env.timeout(time)
    
    def drinks_station(self, student):
        time = randint(5, 20)
        student.cashbox_time += randint(5, 10)
        print("drinks time:", time)
        yield student.env.timeout(time) 
    
    def cashbox(self, student):
        yield student.env.timeout(student.cashbox_time)
        
    def start(self):
        self.mean_hot_queue  = 0
        self.mean_cold_queue = 0
        self.mean_cash_queue = 0
        self.mean_all = 0
        
        self.max_hot_queue  = 0
        self.max_cold_queue = 0
        self.max_cash_queue = 0
        self.max_all = 0
        tick = 0
        while True:
            yield self.env.timeout(1)
            self.mean_hot_queue = self.mean_hot_queue * tick + self.stations["hot"][2]
            self.mean_cold_queue = self.mean_cold_queue * tick + self.stations["cold"][2]
            self.mean_cash_queue = self.mean_cash_queue * tick + sum([cash[2] for cash in self.cashboxes]) / CASHBOX_NUMBER
            all_students = self.stations["hot"][2] + self.stations["cold"][2] + sum([cash[2] for cash in self.cashboxes])
            self.mean_all = self.mean_all * tick + all_students
            tick += 1 
            
            self.mean_hot_queue /= tick
            self.mean_cold_queue /= tick
            self.mean_cash_queue /= tick
            self.mean_all /= tick
            
            if self.stations["hot"][2] > self.max_hot_queue:
                self.max_hot_queue = self.stations["hot"][2]
            if self.stations["cold"][2] > self.max_cold_queue:
                self.max_cold_queue = self.stations["cold"][2]
            if max([cash[2] for cash in self.cashboxes]) > self.max_cash_queue:
                self.max_cash_queue = max([cash[2] for cash in self.cashboxes])
            if all_students > self.max_all:
                self.max_all = all_students

# %%
env = smp.Environment()
cnt = Canteen(env)
env.process(gen_group(env, cnt))
env.run(until=90*60)
# Out:
# Студент 0 направился к hot
# Студент 0 начал обслуживание у hot_station в 15.229204386814034
# hot time: 77
# Студент 1 направился к hot
# Студент 2 направился к hot
# Студент 3 направился к hot
# Студент 0 покинул hot_station в 92.22920438681403
# Студент 0 начал обслуживание у drinks_station  в 92.22920438681403
# drinks time: 18
# Студент 1 начал обслуживание у hot_station в 92.22920438681403
# hot time: 120
# Студент 4 направился к hot
# Студент 5 направился к hot
# Студент 0 покинул drinks_station в 110.22920438681403
# [0, 0]
# Студент 0 прибыл к кассе #0 в 110.22920438681403
# HOT_WAY queue DELAY 0.0
# Студент 0 начал обслуживание у кассы #0 в 110.22920438681403
# Студент 6 направился к hot
# Студент 7 направился к hot
# Студент 8 направился к hot
# Студент 9 направился к hot
# Студент 10 направился к hot
# Студент 11 направился к drinks
# Студент 11 начал обслуживание у drinks_station  в 158.34020001747493
# drinks time: 14
# Студент 0 покинул кассу #0 в 159.22920438681405
# Студент 0 обслуживался 2:24
# Студент 11 покинул drinks_station в 172.34020001747493
# [0, 0]
# Студент 11 прибыл к кассе #0 в 172.34020001747493
# Студент 11 начал обслуживание у кассы #0 в 172.34020001747493
# Студент 11 покинул кассу #0 в 177.34020001747493
# Студент 11 обслуживался 0:19
# Студент 1 покинул hot_station в 212.22920438681405
# Студент 1 начал обслуживание у drinks_station  в 212.22920438681405
# drinks time: 19
# Студент 2 начал обслуживание у hot_station в 212.22920438681405
# hot time: 118
# Студент 1 покинул drinks_station в 231.22920438681405
# [0, 0]
# Студент 1 прибыл к кассе #0 в 231.22920438681405
# HOT_WAY queue DELAY 0.0
# Студент 1 начал обслуживание у кассы #0 в 231.22920438681405
# Студент 12 направился к hot
# Студент 1 покинул кассу #0 в 280.22920438681405
# Студент 1 обслуживался 4:18
# Студент 13 направился к hot
# Студент 14 направился к hot
# Студент 15 направился к hot
# Студент 16 направился к hot
# Студент 17 направился к hot
# Студент 18 направился к hot
# Студент 2 покинул hot_station в 330.22920438681405
# Студент 2 начал обслуживание у drinks_station  в 330.22920438681405
# drinks time: 12
# Студент 3 начал обслуживание у hot_station в 330.22920438681405
# hot time: 112
# Студент 2 покинул drinks_station в 342.22920438681405
# [0, 0]
# Студент 2 прибыл к кассе #0 в 342.22920438681405
# HOT_WAY queue DELAY 0.0
# Студент 2 начал обслуживание у кассы #0 в 342.22920438681405
# Студент 19 направился к hot
# Студент 20 направился к hot
# Студент 21 направился к hot
# Студент 2 покинул кассу #0 в 388.22920438681405
# Студент 2 обслуживался 6:06
# Студент 22 направился к hot
# Студент 23 направился к hot
# Студент 24 направился к hot
# Студент 3 покинул hot_station в 442.22920438681405
# Студент 3 начал обслуживание у drinks_station  в 442.22920438681405
# drinks time: 6
# Студент 4 начал обслуживание у hot_station в 442.22920438681405
# hot time: 83
# Студент 3 покинул drinks_station в 448.22920438681405
# [0, 0]
# Студент 3 прибыл к кассе #0 в 448.22920438681405
# HOT_WAY queue DELAY 0.0
# Студент 3 начал обслуживание у кассы #0 в 448.22920438681405
# Студент 25 направился к hot
# Студент 26 направился к hot
# Студент 27 направился к hot
# Студент 3 покинул кассу #0 в 477.22920438681405
# Студент 3 обслуживался 7:09
# Студент 4 покинул hot_station в 525.229204386814
# Студент 4 начал обслуживание у drinks_station  в 525.229204386814
# drinks time: 13
# Студент 5 начал обслуживание у hot_station в 525.229204386814
# hot time: 116
# Студент 4 покинул drinks_station в 538.229204386814
# [0, 0]
# Студент 4 прибыл к кассе #0 в 538.229204386814
# HOT_WAY queue DELAY 0.0
# Студент 4 начал обслуживание у кассы #0 в 538.229204386814
# Студент 28 направился к hot
# Студент 29 направился к hot
# Студент 30 направился к hot
# Студент 4 покинул кассу #0 в 570.229204386814
# Студент 4 обслуживался 7:56
# Студент 31 направился к hot
# Студент 32 направился к hot
# Студент 5 покинул hot_station в 641.229204386814
# Студент 5 начал обслуживание у drinks_station  в 641.229204386814
# drinks time: 19
# Студент 6 начал обслуживание у hot_station в 641.229204386814
# hot time: 54
# Студент 33 направился к hot
# Студент 5 покинул drinks_station в 660.229204386814
# [0, 0]
# Студент 5 прибыл к кассе #0 в 660.229204386814
# HOT_WAY queue DELAY 0.0
# Студент
229204386814
# HOT_WAY queue DELAY 0.0
# Студент 10 начал обслуживание у кассы #0 в 1085.229204386814
# Студент 58 направился к hot
# Студент 10 покинул кассу #0 в 1112.229204386814
# Студент 10 обслуживался 15:53
# Студент 12 покинул hot_station в 1123.229204386814
# Студент 12 начал обслуживание у drinks_station  в 1123.229204386814
# drinks time: 10
# Студент 13 начал обслуживание у hot_station в 1123.229204386814
# hot time: 76
# Студент 59 направился к cold
# Студент 59 начал обслуживание у cold_station в 1128.7678034814599
# 59 student's cold time: 138
# Студент 12 покинул drinks_station в 1133.229204386814
# [0, 0]
# Студент 12 прибыл к кассе #0 в 1133.229204386814
# HOT_WAY queue DELAY 0.0
# Студент 12 начал обслуживание у кассы #0 в 1133.229204386814
# Студент 60 направился к hot
# Студент 61 направился к hot
# Студент 62 направился к hot
# Студент 63 направился к hot
# Студент 64 направился к hot
# Студент 65 направился к hot
# Студент 66 направился к hot
# Студент 67 направился к cold
# Студент 12 покинул кассу #0 в 1175.229204386814
# Студент 12 обслуживался 15:16
# Студент 68 направился к cold
# Студент 69 направился к cold
# Студент 70 направился к hot
# Студент 13 покинул hot_station в 1199.229204386814
# Студент 13 начал обслуживание у drinks_station  в 1199.229204386814
# drinks time: 5
# Студент 14 начал обслуживание у hot_station в 1199.229204386814
# hot time: 108
# Студент 13 покинул drinks_station в 1204.229204386814
# [0, 0]
# Студент 13 прибыл к кассе #0 в 1204.229204386814
# HOT_WAY queue DELAY 0.0
# Студент 13 начал обслуживание у кассы #0 в 1204.229204386814
# Студент 13 покинул кассу #0 в 1247.229204386814
# Студент 13 обслуживался 16:00
# Студент 71 направился к hot
# Студент 59 покинул cold_station в 1266.7678034814599
# Студент 59 начал обслуживание у drinks_station  в 1266.7678034814599
# drinks time: 14
# Студент 67 начал обслуживание у cold_station в 1266.7678034814599
# 67 student's cold time: 89
# Студент 72 направился к hot
# Студент 73 направился к hot
# Студент 59 покинул drinks_station в 1280.7678034814599
# [0, 0]
# Студент 59 прибыл к кассе #0 в 1280.7678034814599
# COLD_WAY queue DELAY 0.0
# Студент 59 начал обслуживание у кассы #0 в 1280.7678034814599
# Студент 74 направился к hot
# Студент 75 направился к hot
# Студент 59 покинул кассу #0 в 1300.7678034814599
# Студент 59 обслуживался 2:52
# Студент 14 покинул hot_station в 1307.229204386814
# Студент 14 начал обслуживание у drinks_station  в 1307.229204386814
# drinks time: 17
# Студент 15 начал обслуживание у hot_station в 1307.229204386814
# hot time: 74
# Студент 14 покинул drinks_station в 1324.229204386814
# [0, 0]
# Студент 14 прибыл к кассе #0 в 1324.229204386814
# HOT_WAY queue DELAY 0.0
# Студент 14 начал обслуживание у кассы #0 в 1324.229204386814
# Студент 67 покинул cold_station в 1355.7678034814599
# Студент 67 начал обслуживание у drinks_station  в 1355.7678034814599
# drinks time: 7
# Студент 68 начал обслуживание у cold_station в 1355.7678034814599
# 68 student's cold time: 63
# Студент 67 покинул drinks_station в 1362.7678034814599
# [1, 0]
# Студент 67 прибыл к кассе #1 в 1362.7678034814599
# COLD_WAY queue DELAY 0.0
# Студент 67 начал обслуживание у кассы #1 в 1362.7678034814599
# Студент 14 покинул кассу #0 в 1365.229204386814
# Студент 14 обслуживался 17:58
# Студент 67 покинул кассу #1 в 1376.7678034814599
# Студент 67 обслуживался 3:22
# Студент 15 покинул hot_station в 1381.229204386814
# Студент 15 начал обслуживание у drinks_station  в 1381.229204386814
# drinks time: 20
# Студент 16 начал обслуживание у hot_station в 1381.229204386814
# hot time: 61
# Студент 15 покинул drinks_station в 1401.229204386814
# [0, 0]
# Студент 15 прибыл к кассе #0 в 1401.229204386814
# HOT_WAY queue DELAY 0.0
# Студент 15 начал обслуживание у кассы #0 в 1401.229204386814
# Студент 68 покинул cold_station в 1418.7678034814599
# Студент 68 начал обслуживание у drinks_station  в 1418.7678034814599
# drinks time: 14
# Студент 69 начал обслуживание у cold_station в 1418.7678034814599
# 69 student's cold time: 105
# Студент 68 покинул drinks_station в 1432.7678034814599
# [1, 0]
# Студент 68 прибыл к кассе #1 в 1432.7678034814599
# COLD_WAY queue DELAY 0.0
# Студент 68 начал обслуживание у кассы #1 в 1432.7678034814599
# Студент 16 покинул hot_station в 1442.229204386814
# Студент 16 начал обслуживание у drinks_station  в 1442.229204386814
# drinks time: 12
# Студент 17 начал обслуживание у hot_station в 1442.229204386814
# hot time: 95
# Студент 15 покинул кассу #0 в 1450.229204386814
# Студент 15 обслуживался 19:14
# Студент 68 покинул кассу #1 в 1452.7678034814599
# Студент 68 обслуживался 4:28
# Студент 16 покинул drinks_station в 1454.229204386814
# [0, 0]
# Студент 16 прибыл к кассе #0 в 1454.229204386814
# HOT_WAY queue DELAY 0.0
# Студент 16 начал обслуживание у кассы #0 в 1454.229204386814
# Студент 76 направился к hot
# Студент 77 направился к cold
# Студент 16 покинул кассу #0 в 1499.229204386814
# Студент 16 обслуживался 20:03
# Студент 78 направился к hot
# Студент 79 направился к hot
# Студент 80 направился к hot
# Студент 81 направился к hot
# Студент 82 направился к drinks
# Студент 82 начал обслуживание у drinks_station  в 1517.0609197081985
# drinks time: 18
# Студент 83 направился к cold
# Студент 84 направился к hot
# Студент 69 покинул cold_station в 1523.7678034814599
# Студент 69 начал обслуживание у drinks_station  в 1523.7678034814599
# drinks time: 6
# Студент 77 начал обслуживание у cold_station в 1523.7678034814599
# 77 student's cold time: 144
# Студент 69 покинул drinks_station в 1529.7678034814599
# [0, 0]
# Студент 69 прибыл к кассе #0 в 1529.7678034814599
# COLD_WAY queue DELAY 0.0
# Студент 69 начал обслуживание у кассы #0 в 1529.7678034814599
# Студент 82 покинул drinks_station в 1535.0609197081985
# [1, 0]
# Студент 82 прибыл к кассе #1 в 1535.0609197081985
# Студент 82 начал обслуживание у кассы #1 в 1535.0609197081985
# Студент 17 покинул hot_station в 1537.229204386814
# Студент 17 начал обслуживание у drinks_station  в 1537.229204386814
# drinks time: 16
# Студент 18 начал обслуживание у hot_station в 1537.229204386814
# hot time: 58
# Студент 82 покинул кассу #1 в 1540.0609197081985
# Студент 82 обслуживался 0:23
# Студент 85 направился к hot
# Студент 69 покинул кассу #0 в 1546.7678034814599
# Студент 69 обслуживался 6:02
# Студент 17 покинул drinks_station в 1553.229204386814
# [0, 0]
# Студент 17 прибыл к кассе #0 в 1553.229204386814
# HOT_WAY queue DELAY 0.0
# Студент 17 начал обслуживание у кассы #0 в 1553.229204386814
# Студент 86 направился к cold
# Студент 87 направился к hot
# Студент 17 покинул кассу #0 в 1585.229204386814
# Студент 17 обслуживался 21:29
# Студент 18 покинул hot_station в 1595.229204386814
# Студент 18 начал обслуживание у drinks_station  в 1595.229204386814
# drinks time: 12
# Студент 19 начал обслуживание у hot_station в 1595.229204386814
# hot time: 109
# Студент 18 покинул drinks_station в 1607.229204386814
# [0, 0]
# Студент 18 прибыл к кассе #0 в 1607.229204386814
# HOT_WAY queue DELAY 0.0
# Студент 18 начал обслуживание у кассы #0 в 1607.229204386814
# Студент 88 направился к hot
# Студент 89 направился к hot
# Студент 18 покинул кассу #0 в 1652.229204386814
# Студент 18 обслуживался 22:12
# Студент 77 покинул cold_station в 1667.7678034814599
# Студент 77 начал обслуживание у drinks_station  в 1667.7678034814599
# drinks time: 16
# Студент 83 начал обслуживание у cold_station в 1667.7678034814599
# 83 student's cold time: 175
# Студент 90 направился к hot
# Студент 77 покинул drinks_station в 1683.7678034814599
# [0, 0]
# Студент 77 прибыл к кассе #0 в 1683.7678034814599
# COLD_WAY queue DELAY 0.0
# Студент 77 начал обслуживание у кассы #0 в 1683.7678034814599
# Студент 91 направился к hot
# Студент 92 направился к cold
# Студент 77 покинул кассу #0 в 1701.7678034814599
# Студент 77 обслуживался 4:02
# Студент 19 покинул hot_station в 1704.229204386814
# Студент 19 начал обслуживание у drinks_station  в 1704.229204386814
# drinks time: 13
# Студент 20 начал обслуживание у hot_station в 1704.229204386814
# hot time: 110
# Студент 19 покинул drinks_station в 1717.229204386814
# [0, 0]
# Студент 19 прибыл к кассе #0 в 1717.229204386814
# HOT_WAY queue DELAY 0.0
# Студент 19 начал обслуживание у кассы #0 в 1717.229204386814
# Студент 93 направился к hot
# Студент 94 направился к hot
# Студент 95 направился к hot
# Студент 96 направился к hot
# Студент 97 направился к cold
# Студент 98 направился к hot
# Студент 19 покинул кассу #0 в 1762.229204386814
# Студент 19 обслуживался 23:34
# Студент 99 направился к hot
# Студент 100 направился к hot
# Студент 20 покинул hot_station в 1814.229204386814
# Студент 20 начал обслуживание у drinks_station  в 1814.229204386814
# drinks time: 13
# Студент 21 начал обслуживание у hot_station в 1814.229204386814
# hot time: 60
# Студент 101 направился к cold
# Студент 102 направился к cold
# Студент 20 покинул drinks_station в 1827.229204386814
# [0, 0]
# Студент 20 прибыл к кассе #0 в 1827.229204386814
# HOT_WAY queue DELAY 0.0
# Студент 20 начал обслуживание у кассы #0 в 1827.229204386814
# Студент 103 направился к cold
# Студент 104 направился к hot
# Студент 105 направился к hot
# Студент 106 направился к hot
# Студент 83 покинул cold_station в 1842.7678034814599
# Студент 83 начал обслуживание у drinks_station  в 1842.7678034814599
# drinks time: 12
# Студент 86 начал обслуживание у cold_station в 1842.7678034814599
# 86 student's cold time: 171
# Студент 107 направился к hot
# Студент 20 покинул кассу #0 в 1852.229204386814
# Студент 20 обслуживался 24:56
# Студент 83 покинул drinks_station в 1854.7678034814599
# [0, 0]
# Студент 83 прибыл к кассе #0 в 1854.7678034814599
# COLD_WAY queue DELAY 0.0
# Студент 83 начал обслуживание у кассы #0 в 1854.7678034814599
# %%
mn_hot = sum([std.delays["hot"] for std in STUDETNTS if (std.way == "hot" and std.finished)]) / len([std for std in STUDETNTS if (std.way == "hot" and std.finished)])
print_time("Mean hot delay:", mn_hot)
mx_hot = max([std.delays["hot"] for std in STUDETNTS if std.way == "hot"])
print_time("Max  hot delay", mx_hot)
# Out:
# Mean hot delay: 34:15
# Max  hot delay 68:50

# %%
mn_cold = sum([std.delays["cold"] for std in STUDETNTS if (std.way == "cold" and std.finished)]) / len([std for std in STUDETNTS if (std.way == "cold" and std.finished)])
print_time("Mean cold delay:", mn_cold)
mx_cold = max([std.delays["cold"] for std in STUDETNTS if std.way == "cold"])
print_time("Max  cold delay:", mx_cold)
# Out:
# Mean cold delay: 11:48
# Max  cold delay: 20:46

# %%
mn_cash = sum([std.delays["cash"] for std in STUDETNTS if std.finished]) / len([std for std in STUDETNTS if std.finished])
mx_cash = max([std.delays["cash"] for std in STUDETNTS if std.finished])
print_time("Mean cash delay:", mn_cash)
print_time("Max  cash delay:", mx_cash)
max([std.delays["cash"] for std in STUDETNTS if std.finished])
# Out:
# Mean cash delay: 0:00
# Max  cash delay: 0:00
# 0.0

# %%
print("Mean hot_station queue:", int(cnt.mean_hot_queue))
print("Max  hot_station queue:", cnt.max_hot_queue)
# Out:
# Mean hot_station queue: 92
# Max  hot_station queue: 176

# %%
print("Mean cold_station queue:", int(cnt.mean_cold_queue))
print("Max  cold_station queue:", cnt.max_cold_queue)
# Out:
# Mean cold_station queue: 5
# Max  cold_station queue: 11

# %%
print("Mean cashbox queue:", int(cnt.mean_cash_queue))
print("Max  cashbox queue:", cnt.max_cash_queue)
# Out:
# Mean cashbox queue: 0
# Max  cashbox queue: 1

# %%
type1 = [std for std in STUDETNTS if (std.way == "hot" and std.finished)]
type2 = [std for std in STUDETNTS if (std.way == "cold" and std.finished)]
type3 = [std for std in STUDETNTS if (std.way == "drinks" and std.finished)]
types = [type1, type2, type3]

for i in range(len(types)):
    print_time("Mean queue delay for type{0}:".format(i+1), sum([sum(std.delays.values()) for std in types[i]]) / len(types[i]))
    print_time("Max  queue delay for type{0}:".format(i+1), max([sum(std.delays.values()) for std in types[i]]))
    print()
# Out:
# Mean queue delay for type1: 34:15
# Max  queue delay for type1: 67:35
#
# Mean queue delay for type2: 11:48
# Max  queue delay for type2: 20:46
#
# Mean queue delay for type3: 0:00
# Max  queue delay for type3: 0:00

# %%
mn_total = sum([sum(std.delays.values()) for std in STUDETNTS if std.finished]) / len([std for std in STUDETNTS if std.finished])
print_time("Mean total service time:", mn_total)
# Out:
# Mean total service time: 24:47

# %%
print("Mean ")
# Out:
# Mean

# %%
cnt.max_all
# Out:
# 186

# %%
cnt.mean_all
# Out:
# 98.94313761807746

# %%
print(len(STUDETNTS))
print(len([std for std in STUDETNTS if std.way == "hot"]))
print(len([std for std in STUDETNTS if std.way == "cold"]))
print(len([std for std in STUDETNTS if std.way not in ("hot", "cold")]))
# Out:
# 288
# 238
# 44
# 6

# %%
308/366
# Out:
# 0.8415300546448088

# %%
0.85*85 / (0.15*120)
# Out:
# 4.013888888888889
